# %%
import pandas as pd
import os

# %% [markdown]
# 必要なカラム
# * customer_unique_id@cus_df
# * order_purchase_timestamp@ord_df
# * payment_value@pay_df
#
# フィルタ
# * order_purchase_timestamps@ord_df: 2018/01/01-9/30

# %%
os.chdir('../datasets')

cus_df = pd.read_csv('olist_customers_dataset.csv')
# 必要なカラムのみ
cus_df = cus_df.loc[:, ['customer_unique_id', 'customer_id']].sort_values(by='customer_unique_id')

# 重複確認
# -> OK（customer_unique_idは一意だがcustomer_idは一意でない）
print(cus_df['customer_unique_id'].sort_values().duplicated().value_counts())
print(cus_df['customer_id'].sort_values().duplicated().value_counts())

cus_df
# Out:
# False    96096
# True      3345
# Name: customer_unique_id, dtype: int64
# False    99441
# Name: customer_id, dtype: int64
#                      customer_unique_id                       customer_id
# 64012  0000366f3b9a7992bf8c76cfdf3221e2  fadbb3709178fc513abc1b2670aa1ad2
# 24570  0000b849f77a49e4a4ce2b2a4ca5be3f  4cb282e167ae9234755102258dd52ee8
# 40832  0000f46a3911fa3c0805444483337064  9b3932a6253894a02c1df9d19004239f
# 57118  0000f6ccb0745a6a4b88665a16c9f078  914991f0c02ef0843c0e7010c819d642
# 81150  0004aac84e0df4da2b147fca70cf8255  47227568b10f5f58a524a75507e6992c
# ...                                 ...                               ...
# 89147  fffcf5a5ff07b0908bd4e2dbc735a684  74be082247cd677a147d83ee670e9d53
# 9810   fffea47cd6d3cc0a88bd621562a9d061  0ecf8e0a08148af0bf313184f167670a
# 69017  ffff371b4d645b6ecea244b27531430a  27f584b0f1dc4e610065c240f68b6be0
# 94891  ffff5962728ec6157033ef9805bacc48  832a3b0254347d409512ae92eaf154a6
# 83624  ffffd2657e2aad2907e67c3e9daecbeb  70bc4d9cf2bbeea3f7b09798370f5884
#
# [99441 rows x 2 columns]

# %%
ord_df = pd.read_csv('olist_orders_dataset.csv')
ord_df['order_purchase_timestamp'] = pd.to_datetime(ord_df['order_purchase_timestamp'])
# 必要なカラムのみ
ord_df = ord_df.loc[:, ['order_id', 'customer_id', 'order_purchase_timestamp']]
ord_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_purchase_timestamp
# 0          2017-10-02 10:56:33
# 1          2018-07-24 20:41:37
# 2          2018-08-08 08:38:49
# 3          2017-11-18 19:28:06
# 4          2018-02-13 21:18:39
# ...                        ...
# 99436      2017-03-09 09:54:05
# 99437      2018-02-06 12:58:58
# 99438      2017-08-27 14:46:43
# 99439      2018-01-08 21:28:27
# 99440      2018-03-08 20:57:30
#
# [99441 rows x 3 columns]

# %%
pay_df = pd.read_csv('olist_order_payments_dataset.csv')
# 必要なカラムのみ
pay_df = pay_df.loc[:, ['order_id', 'payment_value']]

# 重複確認
# ->  重複あり（支払いが複数回に渡っている場合など）なので、まとめたい
print(pay_df['order_id'].sort_values().duplicated().value_counts())
# 重複例
display(pay_df[pay_df['order_id'] == '009ac365164f8e06f59d18a08045f6c4'])
display(pay_df[pay_df['order_id'] == '009ac365164f8e06f59d18a08045f6c4'].sum())

# order_idごとにpayment_valueをsumする
pay_df = pay_df.groupby('order_id')['payment_value'].sum().to_frame().reset_index()
# 数値確認
# -> OK
display(pay_df[pay_df.order_id == '009ac365164f8e06f59d18a08045f6c4'])

pay_df
# Out:
# False    99440
# True      4446
# Name: order_id, dtype: int64
#                                order_id  payment_value
# 285    009ac365164f8e06f59d18a08045f6c4           8.75
# 15298  009ac365164f8e06f59d18a08045f6c4           4.17
# 16053  009ac365164f8e06f59d18a08045f6c4           0.88
# 16459  009ac365164f8e06f59d18a08045f6c4           4.50
# 32058  009ac365164f8e06f59d18a08045f6c4           5.45
# 73837  009ac365164f8e06f59d18a08045f6c4           8.25
# order_id         009ac365164f8e06f59d18a08045f6c4009ac365164f8e...
# payment_value                                                   32
# dtype: object
#                              order_id  payment_value
# 215  009ac365164f8e06f59d18a08045f6c4           32.0
#                                order_id  payment_value
# 0      00010242fe8c5a6d1ba2dd792cb16214          72.19
# 1      00018f77f2f0320c557190d7a144bdd3         259.83
# 2      000229ec398224ef6ca0657da4fc703e         216.87
# 3      00024acbcdf0a6daa1e931b038114c75          25.78
# 4      00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                 ...            ...
# 99435  fffc94f6ce00a00581880bf54a75a037         343.40
# 99436  fffcd46ef2263f404302a634eb57f7eb         386.53
# 99437  fffce4705a9662cd70adb13d4a31832d         116.85
# 99438  fffe18544ffabc95dfada21779c9644f          64.71
# 99439  fffe41c64501cc87c801fd61db3f6244          55.79
#
# [99440 rows x 2 columns]

# %%
# マージ
display(ord_df.count())
display(pay_df.count())
merged = pd.merge(ord_df, cus_df, on='customer_id', how='left')
display(merged.count())
print('-----')

display(merged.count())
display(pay_df.count())
merged = pd.merge(merged, pay_df, on='order_id', how='left')
display(merged.count())
print('-----')

merged = merged.loc[:, ['customer_unique_id', 'order_purchase_timestamp', 'payment_value']]
#merged.sort_values(by=['order_purchase_timestamp', 'customer_unique_id'])
merged.sort_values(by=['customer_unique_id', 'order_purchase_timestamp'])
# Out:
# order_id                    99441
# customer_id                 99441
# order_purchase_timestamp    99441
# dtype: int64
# order_id         99440
# payment_value    99440
# dtype: int64
# order_id                    99441
# customer_id                 99441
# order_purchase_timestamp    99441
# customer_unique_id          99441
# dtype: int64
# -----
# order_id                    99441
# customer_id                 99441
# order_purchase_timestamp    99441
# customer_unique_id          99441
# dtype: int64
# order_id         99440
# payment_value    99440
# dtype: int64
# order_id                    99441
# customer_id                 99441
# order_purchase_timestamp    99441
# customer_unique_id          99441
# payment_value               99440
# dtype: int64
# -----
#                      customer_unique_id order_purchase_timestamp  \
# 52798  0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:27
# 73889  0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:27
# 26460  0000f46a3911fa3c0805444483337064      2017-03-10 21:05:03
# 98493  0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:41
# 41564  0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:42
# ...                                 ...                      ...
# 87007  fffcf5a5ff07b0908bd4e2dbc735a684      2017-06-08 21:00:36
# 20556  fffea47cd6d3cc0a88bd621562a9d061      2017-12-10 20:07:56
# 43943  ffff371b4d645b6ecea244b27531430a      2017-02-07 15:49:16
# 96853  ffff5962728ec6157033ef9805bacc48      2018-05-02 15:17:41
# 70017  ffffd2657e2aad2907e67c3e9daecbeb      2017-05-02 20:18:45
#
#        payment_value
# 52798         141.90
# 73889          27.19
# 26460          86.22
# 98493          43.62
# 41564         196.89
# ...              ...
# 87007        2067.42
# 20556          84.58
# 43943         112.46
# 96853         133.69
# 70017          71.56
#
# [99441 rows x 3 columns]

# %%
# 相関なしと判断
summary[['monetary_value', 'frequency']].corr()
# Out:
#                 monetary_value  frequency
# monetary_value        1.000000   0.009506
# frequency             0.009506   1.000000

# %%
# calibrationデータとholdoutデータに分割して検証
# https://github.com/CamDavidsonPilon/lifetimes/blob/master/lifetimes/utils.py#L27
from lifetimes.utils import calibration_and_holdout_data

summary = calibration_and_holdout_data(merged, 'customer_unique_id', 'order_purchase_timestamp',
                                        calibration_period_end='2018-04-30',
                                        monetary_value_col='payment_value')

# ちょっとデータが少なすぎるから期間を調整。。
summary = summary[summary.frequency_cal >0]
summary
# Out:
#                                   frequency_cal  recency_cal  T_cal  \
# customer_unique_id
# 004288347e5e88a27ded2bb23747066c            1.0        171.0  277.0
# 0058f300f57d7b93c477a131a59b36c3            1.0         31.0   70.0
# 011575986092c30523ecb71ff10cb473            1.0         60.0   72.0
# 011b4adcd54683b480c4d841250a987f            1.0        177.0  251.0
# 013f4353d26bb05dc6652f1269458d8d            1.0          4.0  157.0
# ...                                         ...          ...    ...
# fe59d5878cd80080edbd29b5a0a4e1cf            2.0         76.0  327.0
# fe81bb32c243a86b2f86fbf053fe6140            2.0        124.0  190.0
# fed519569d16e690df6f89cb99d4e682            1.0         88.0  131.0
# ff8892f7c26aa0446da53d01b18df463            1.0        186.0  341.0
# ff922bdd6bafcdf99cb90d7f39cea5b3            2.0        204.0  432.0
#
#                                   monetary_value_cal  frequency_holdout  \
# customer_unique_id
# 004288347e5e88a27ded2bb23747066c              103.28                0.0
# 0058f300f57d7b93c477a131a59b36c3               96.02                0.0
# 011575986092c30523ecb71ff10cb473               80.32                0.0
# 011b4adcd54683b480c4d841250a987f              149.88                0.0
# 013f4353d26bb05dc6652f1269458d8d              164.04                0.0
# ...                                              ...                ...
# fe59d5878cd80080edbd29b5a0a4e1cf               39.60                0.0
# fe81bb32c243a86b2f86fbf053fe6140               71.33                2.0
# fed519569d16e690df6f89cb99d4e682              110.26                0.0
# ff8892f7c26aa0446da53d01b18df463               66.74                0.0
# ff922bdd6bafcdf99cb90d7f39cea5b3               50.09                0.0
#
#                                   monetary_value_holdout  duration_holdout
# customer_unique_id
# 004288347e5e88a27ded2bb23747066c                    0.00               170
# 0058f300f57d7b93c477a131a59b36c3                    0.00               170
# 011575986092c30523ecb71ff10cb473                    0.00               170
# 011b4adcd54683b480c4d841250a987f                    0.00               170
# 013f4353d26bb05dc6652f1269458d8d                    0.00               170
# ...                                                  ...               ...
# fe59d5878cd80080edbd29b5a0a4e1cf                    0.00               170
# fe81bb32c243a86b2f86fbf053fe6140                  692.16               170
# fed519569d16e690df6f89cb99d4e682                    0.00               170
# ff8892f7c26aa0446da53d01b18df463                    0.00               170
# ff922bdd6bafcdf99cb90d7f39cea5b3                    0.00               170
#
# [1372 rows x 7 columns]

# %%
# 購買期間確認
# -> 2016/09-2018/10末あたり
merged.sort_values(by='order_purchase_timestamp')
# Out:
#                      customer_unique_id order_purchase_timestamp  \
# 4541   b7d76e111c89f7ebf14761390f0f7d17      2016-09-04 21:15:19
# 4396   4854e9b3feff728c13ee5fc7d1547e92      2016-09-05 00:15:34
# 10071  009b0127b727ab0ba422f6d9604487c7      2016-09-13 15:24:19
# 30710  830d5b7aaa3b6f1e9ad63703bec97d23      2016-09-15 12:16:38
# 83078  0eb1ee9dba87f5b36b4613a65074337c      2016-10-02 22:07:52
# ...                                 ...                      ...
# 50387  9bb92bebd4cb7511e1a02d5e50bc4655      2018-09-29 09:13:03
# 88500  634420a0ea42302205032ed44ac7fccc      2018-10-01 15:30:09
# 31891  af5454198a97379394cacf676e1e96cb      2018-10-03 18:55:29
# 68373  262e1f1e26e92e86375f86840b4ffd63      2018-10-16 20:16:02
# 60938  87ab9fec999db8bd5774917de3cdf01c      2018-10-17 17:30:18
#
#        payment_value
# 4541          136.23
# 4396           75.06
# 10071          40.95
# 30710            NaN
# 83078         109.34
# ...              ...
# 50387         137.03
# 88500          80.38
# 31891         197.55
# 68373         222.03
# 60938          89.71
#
# [99441 rows x 3 columns]

# %%
from lifetimes import GammaGammaFitter

ggf = GammaGammaFitter(penalizer_coef = 0)
ggf.fit(summary['frequency_cal'],
        summary['monetary_value_cal'])
print(ggf)
# Out:
# <lifetimes.GammaGammaFitter: fitted with 1372 subjects, p: 5.61, q: 2.82, v: 49.29>

# %%
# 想定される利用金額（LifeTimeValue）
display(ggf.conditional_expected_average_profit(
        summary['frequency_cal'],
        summary['monetary_value_cal']).sort_values(ascending=False))
# Out:
# customer_unique_id
# 055ec572ac7f3c7bdd04a183830ebe59    1567.634290
# a1044dd75b74fbc485b040575a14acf0    1283.412734
# da1e7179b9c5a1494d78528cbcf05aa0    1088.280393
# 58c1b085b54c03a1f1ab5f13d64c2b1c    1080.366050
# 6e26bbeaa107ec34112c64e1ee31c0f5    1076.695850
#                                        ...
# a74e3f2f887f14862e34c61ed0e4c5d0      49.938304
# 53100f780630b0755dcdec40f673abfb      49.220878
# 6eefa309faab7725bf4b9dce147e4ae6      48.140548
# 1c4531b533d17f3b316de441268e513c      47.853992
# e1224167b1a3f92781c2ff55b0b794be      35.860939
# Length: 1372, dtype: float64

# %%
# 2018-04-30までのデータで推定
# 観察データは2018/10末まで

# 平均トランザクション: 1567.634290
display(merged[merged.customer_unique_id == '055ec572ac7f3c7bdd04a183830ebe59'])

# 平均トランザクション: 1283.412734
display(merged[merged.customer_unique_id == 'a1044dd75b74fbc485b040575a14acf0'])

# 平均トランザクション: 1088.280393
display(merged[merged.customer_unique_id == 'da1e7179b9c5a1494d78528cbcf05aa0'])
# Out:
#                      customer_unique_id order_purchase_timestamp  \
# 31193  055ec572ac7f3c7bdd04a183830ebe59      2017-06-18 17:22:09
# 39386  055ec572ac7f3c7bdd04a183830ebe59      2017-07-18 18:49:15
#
#        payment_value
# 31193        2026.54
# 39386        2026.54
#                      customer_unique_id order_purchase_timestamp  \
# 46757  a1044dd75b74fbc485b040575a14acf0      2017-12-20 23:22:55
# 64907  a1044dd75b74fbc485b040575a14acf0      2017-12-12 18:19:22
#
#        payment_value
# 46757        1650.18
# 64907          87.70
#                      customer_unique_id order_purchase_timestamp  \
# 579    da1e7179b9c5a1494d78528cbcf05aa0      2017-05-19 14:12:50
# 13921  da1e7179b9c5a1494d78528cbcf05aa0      2017-11-09 11:20:34
#
#        payment_value
# 579            76.08
# 13921        1391.79
